# %%
import sys
print(sys.executable)
# Out:
# /Users/vi/Code/mac-gemma-haiku/.venv/bin/python

# %%
import pandas as pd
from pprint import pprint

# %%
df = pd.read_json("../../data/raw/haikus.json")

# %%
df.head()
# Out:
#                                        conversations
# 0  [{'from': 'human', 'value': 'What is the capit...
# 1  [{'from': 'human', 'value': 'How do I fix a le...
# 2  [{'from': 'human', 'value': 'Tell me about bla...
# 3  [{'from': 'human', 'value': 'What is the squar...
# 4  [{'from': 'human', 'value': 'Who painted the M...

# %%
pprint(df.iloc[0]["conversations"])
# Out:
# [{'from': 'human', 'value': 'What is the capital of France?'},
#  {'from': 'gpt',
#   'value': 'City of bright lights,\n'
#            'Paris stands by river Seine,\n'
#            'Heart of French culture.'}]

# %%
# https://github.com/unslothai/unsloth/blob/main/unsloth/chat_templates.py
