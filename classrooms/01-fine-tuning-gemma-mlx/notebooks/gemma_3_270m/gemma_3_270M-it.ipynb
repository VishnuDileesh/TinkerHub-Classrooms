# %%
import os
from mlx_tune import FastLanguageModel
from mlx_lm import generate
from mlx_tune.chat_templates import get_chat_template

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "google/gemma-3-270m-it",
    max_seq_length = 2048,
    load_in_4bit = False
)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "gemma-3",
)

# %%
response = generate(model, tokenizer, prompt="Explain quantum computing in one sentence.", max_tokens=64)

# %%
print(response)
# Out:
# Quantum computing leverages the principles of quantum mechanics to perform computations that are impossible for classical computers. This allows for exponentially faster processing speeds and the ability to tackle problems that are intractable for even the most powerful supercomputers.
